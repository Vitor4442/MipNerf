# %%
# !sudo apt-get update -y
# !sudo apt-get install -y colmap imagemagick
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://cli.github.com/packages stable/main amd64 Packages [357 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [85.0 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,910 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# ...

# %%
# !git clone https://github.com/google-research/multinerf.git
# %cd multinerf
# !pip install -r requirements.txt
# !pip install -e .
# Out:
# Cloning into 'multinerf'...
# remote: Enumerating objects: 270, done.
# remote: Counting objects: 100% (182/182), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 270 (delta 145), reused 117 (delta 117), pack-reused 88 (from 1)
# Receiving objects: 100% (270/270), 174.34 KiB | 10.25 MiB/s, done.
# Resolving deltas: 100% (157/157), done.
# /content/multinerf
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 43.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.0/101.0 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 54.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 3.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: toolz
#     Found existing installation: toolz 0.12.1
#     Uninstalling toolz-0.12.1:
# ...

# %%
# !git clone https://github.com/rmbrualla/pycolmap.git ./internal/pycolmap
# Out:
# Cloning into './internal/pycolmap'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 68 (delta 11), reused 7 (delta 7), pack-reused 40 (from 1)
# Receiving objects: 100% (68/68), 29.58 KiB | 9.86 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !sed -i 's/--SiftExtraction.use_gpu 1/--SiftExtraction.use_gpu 0/g' scripts/local_colmap_and_resize.sh
# !sed -i 's/--SiftMatching.use_gpu 1/--SiftMatching.use_gpu 0/g' scripts/local_colmap_and_resize.sh
# !sed -i 's/use_gpu "$USE_GPU"/use_gpu 0/g' scripts/local_colmap_and_resize.sh
# !sed -i 's/exhaustive_matcher/sequential_matcher/g' scripts/local_colmap_and_resize.sh

# %%
# %env DATA_DIR=/content/drive/MyDrive/DataSetDrone
# %env QT_QPA_PLATFORM=offscreen
# !bash scripts/local_colmap_and_resize.sh ${DATA_DIR}
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Pose refinement report
# ----------------------
#     Residuals : 1492
#    Parameters : 6
#    Iterations : 8
#          Time : 0.028019 [s]
#  Initial cost : 0.628025 [px]
#    Final cost : 0.602548 [px]
#   Termination : Convergence
#
#   => Continued observations: 668
#   => Added observations: 238
#
# Bundle adjustment report
# ------------------------
#     Residuals : 11332
#    Parameters : 1058
#    Iterations : 26
#          Time : 0.942592 [s]
#  Initial cost : 0.677901 [px]
#    Final cost : 0.668047 [px]
#   Termination : No convergence
#
#   => Merged observations: 114
#   => Completed observations: 166
#   => Filtered observations: 98
#   => Changed observations: 0.058989
#
# Bundle adjustment report
# ------------------------
#     Residuals : 11558
#    Parameters : 1043
#    Iterations : 3
#          Time : 0.083787 [s]
#  Initial cost : 0.847971 [px]
#    Final cost : 0.840083 [px]
# ...
